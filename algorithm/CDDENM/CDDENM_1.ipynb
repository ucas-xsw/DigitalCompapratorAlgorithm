# %%
import numpy as np
from scipy.optimize import minimize
from deap import algorithms, base, creator, tools

# Define the objective function and constraints
def objective(x):
    return -(x[0]*x[1]*x[2])

def constraint1(x):
    return x[0] + x[1] + x[2] - 5

def constraint2(x):
    return x[0]**2 + x[1]**2 + x[2]**2 - 25

# Implement the Nelder Mead algorithm
x0 = np.array([1, 1, 1])
result = minimize(objective, x0, method='nelder-mead')

# Implement the differential evolution algorithm
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)
toolbox = base.Toolbox()
toolbox.register("attr_bool", np.random.randint, 0, 2)
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_bool, 3)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)
toolbox.register("evaluate", objective)
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutFlipBit, indpb=0.05)
toolbox.register("select", tools.selTournament, tournsize=3)
toolbox.register("constraint1", constraint1)
toolbox.decorate("constraint1", tools.DeltaPenalty)
toolbox.register("constraint2", constraint2)
toolbox.decorate("constraint2", tools.DeltaPenalty)

# Combine the two algorithms
def nelder_mead(population, toolbox, ngen, step=1):
    for i in range(ngen):
        best = tools.selBest(population, 1)[0]
        population = [best] + list(algorithms.varAnd(population, toolbox, cxpb=0.5, mutpb=0.2))
        population = [toolbox.constraint1(ind) for ind in population]
        population = [toolbox.constraint2(ind) for ind in population]
    return population

pop = toolbox.population(n=10)
pop = nelder_mead(pop, toolbox, ngen=10)
result = algorithms.eaSimple(pop, toolbox, cxpb=0.5, mutpb=0.2, ngen=20)

# Record the optimal value at each iteration
optimal_values = []
for ind in result:
    optimal_values.append(ind.fitness.values[0])

# Plot the curve of optimal value versus iterations
import matplotlib.pyplot as plt
plt.plot(optimal_values)
plt.xlabel('Iterations')
plt.ylabel('Optimal value')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 31
#      29 toolbox.register("select", tools.selTournament, tournsize=3)
#      30 toolbox.register("constraint1", constraint1)
# ---> 31 toolbox.decorate("constraint1", tools.DeltaPenalty)
#      32 toolbox.register("constraint2", constraint2)
#      33 toolbox.decorate("constraint2", tools.DeltaPenalty)
#
# File d:\Programs\anaconda3\envs\test\Lib\site-packages\deap\base.py:121, in Toolbox.decorate(self, alias, *decorators)
#     119 function, args, kargs = pfunc.func, pfunc.args, pfunc.keywords
#     120 for decorator in decorators:
# --> 121     function = decorator(function)
#     122 self.register(alias, function, *args, **kargs)
#
# TypeError: DeltaPenalty.__init__() missing 1 required positional argument: 'delta'

# %%
import numpy as np
from scipy.optimize import minimize
from deap import algorithms, base, creator, tools

# Define the objective function and constraints
def objective(x):
    return -(x[0]*x[1]*x[2])

def constraint1(x):
    return x[0] + x[1] + x[2] - 5

def constraint2(x):
    return x[0]**2 + x[1]**2 + x[2]**2 - 25

# Implement the Nelder Mead algorithm
x0 = np.array([1, 1, 1])
result = minimize(objective, x0, method='nelder-mead')

# Implement the differential evolution algorithm
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)
toolbox = base.Toolbox()
toolbox.register("attr_bool", np.random.randint, 0, 2)
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_bool, 3)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)
toolbox.register("evaluate", objective)
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutFlipBit, indpb=0.05)
toolbox.register("select", tools.selTournament, tournsize=3)
toolbox.register("constraint1", constraint1)
toolbox.decorate("constraint1", tools.DeltaPenalty)
toolbox.register("constraint2", constraint2)
toolbox.decorate("constraint2", tools.DeltaPenalty)

# Combine the two algorithms
def nelder_mead(population, toolbox, ngen, step=1):
    for i in range(ngen):
        best = tools.selBest(population, 1)[0]
        population = [best] + list(algorithms.varAnd(population, toolbox, cxpb=0.5, mutpb=0.2))
        population = [toolbox.constraint1(ind) for ind in population]
        population = [toolbox.constraint2(ind) for ind in population]
    return population

pop = toolbox.population(n=10)
pop = nelder_mead(pop, toolbox, ngen=10)
result = algorithms.eaSimple(pop, toolbox, cxpb=0.5, mutpb=0.2, ngen=20)

# Record the optimal value at each iteration
optimal_values = []
for ind in result:
    optimal_values.append(ind.fitness.values[0])

# Plot the curve of optimal value versus iterations
import matplotlib.pyplot as plt
plt.plot(optimal_values)
plt.xlabel('Iterations')
plt.ylabel('Optimal value')
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[1], line 31
#
#      29 toolbox.register("select", tools.selTournament, tournsize=3)
#
#      30 toolbox.register("constraint1", constraint1)
#
# ---> 31 toolbox.decorate("constraint1", tools.DeltaPenalty)
#
#      32 toolbox.register("constraint2", constraint2)
#
#      33 toolbox.decorate("constraint2", tools.DeltaPenalty)
#
#
#
# File d:\Programs\anaconda3\envs\test\Lib\site-packages\deap\base.py:121, in Toolbox.decorate(self, alias, *decorators)
#
#     119 function, args, kargs = pfunc.func, pfunc.args, pfunc.keywords
#
#     120 for decorator in decorators:
#
# --> 121     function = decorator(function)
#
#     122 self.register(alias, function, *args, **kargs)
#
#
#
# TypeError: DeltaPenalty.__init__() missing 1 required positional argument: 'delta'

# %%
import numpy as np
from scipy.optimize import minimize
from deap import algorithms, base, creator, tools

# Define the objective function and constraints
def objective(x):
    return -(x[0]*x[1]*x[2])

def constraint1(x):
    return x[0] + x[1] + x[2] - 5

def constraint2(x):
    return x[0]**2 + x[1]**2 + x[2]**2 - 25

# Implement the Nelder Mead algorithm
x0 = np.array([1, 1, 1])
result = minimize(objective, x0, method='nelder-mead')

# Implement the differential evolution algorithm
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)
toolbox = base.Toolbox()
toolbox.register("attr_bool", np.random.randint, 0, 2)
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_bool, 3)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)
toolbox.register("evaluate", objective)
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutFlipBit, indpb=0.05)
toolbox.register("select", tools.selTournament, tournsize=3)
toolbox.register("constraint1", constraint1)
toolbox.decorate("constraint1", tools.DeltaPenalty)
toolbox.register("constraint2", constraint2)
toolbox.decorate("constraint2", tools.DeltaPenalty)

# Combine the two algorithms
def nelder_mead(population, toolbox, ngen, step=1):
    for i in range(ngen):
        best = tools.selBest(population, 1)[0]
        population = [best] + list(algorithms.varAnd(population, toolbox, cxpb=0.5, mutpb=0.2))
        population = [toolbox.constraint1(ind) for ind in population]
        population = [toolbox.constraint2(ind) for ind in population]
    return population

pop = toolbox.population(n=10)
pop = nelder_mead(pop, toolbox, ngen=10)
result = algorithms.eaSimple(pop, toolbox, cxpb=0.5, mutpb=0.2, ngen=20)

# Record the optimal value at each iteration
optimal_values = []
for ind in result:
    optimal_values.append(ind.fitness.values[0])

# Plot the curve of optimal value versus iterations
import matplotlib.pyplot as plt
plt.plot(optimal_values)
plt.xlabel('Iterations')
plt.ylabel('Optimal value')
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[1], line 31
#
#      29 toolbox.register("select", tools.selTournament, tournsize=3)
#
#      30 toolbox.register("constraint1", constraint1)
#
# ---> 31 toolbox.decorate("constraint1", tools.DeltaPenalty)
#
#      32 toolbox.register("constraint2", constraint2)
#
#      33 toolbox.decorate("constraint2", tools.DeltaPenalty)
#
#
#
# File d:\Programs\anaconda3\envs\test\Lib\site-packages\deap\base.py:121, in Toolbox.decorate(self, alias, *decorators)
#
#     119 function, args, kargs = pfunc.func, pfunc.args, pfunc.keywords
#
#     120 for decorator in decorators:
#
# --> 121     function = decorator(function)
#
#     122 self.register(alias, function, *args, **kargs)
#
#
#
# TypeError: DeltaPenalty.__init__() missing 1 required positional argument: 'delta'

# %%
import numpy as np
from scipy.optimize import minimize
from deap import algorithms, base, creator, tools

# Define the objective function and constraints
def objective(x):
    return -(x[0]*x[1]*x[2])

def constraint1(x):
    return x[0] + x[1] + x[2] - 5

def constraint2(x):
    return x[0]**2 + x[1]**2 + x[2]**2 - 25

# Implement the Nelder Mead algorithm
x0 = np.array([1, 1, 1])
result = minimize(objective, x0, method='nelder-mead')

# Implement the differential evolution algorithm
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)
toolbox = base.Toolbox()
toolbox.register("attr_bool", np.random.randint, 0, 2)
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_bool, 3)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)
toolbox.register("evaluate", objective)
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutFlipBit, indpb=0.05)
toolbox.register("select", tools.selTournament, tournsize=3)
toolbox.register("constraint1", constraint1)
toolbox.decorate("constraint1", tools.DeltaPenalty)
toolbox.register("constraint2", constraint2)
toolbox.decorate("constraint2", tools.DeltaPenalty)

# Combine the two algorithms
def nelder_mead(population, toolbox, ngen, step=1):
    for i in range(ngen):
        best = tools.selBest(population, 1)[0]
        population = [best] + list(algorithms.varAnd(population, toolbox, cxpb=0.5, mutpb=0.2))
        population = [toolbox.constraint1(ind) for ind in population]
        population = [toolbox.constraint2(ind) for ind in population]
    return population

pop = toolbox.population(n=10)
pop = nelder_mead(pop, toolbox, ngen=10)
result = algorithms.eaSimple(pop, toolbox, cxpb=0.5, mutpb=0.2, ngen=20)

# Record the optimal value at each iteration
optimal_values = []
for ind in result:
    optimal_values.append(ind.fitness.values[0])

# Plot the curve of optimal value versus iterations
import matplotlib.pyplot as plt
plt.plot(optimal_values)
plt.xlabel('Iterations')
plt.ylabel('Optimal value')
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[1], line 31
#
#      29 toolbox.register("select", tools.selTournament, tournsize=3)
#
#      30 toolbox.register("constraint1", constraint1)
#
# ---> 31 toolbox.decorate("constraint1", tools.DeltaPenalty)
#
#      32 toolbox.register("constraint2", constraint2)
#
#      33 toolbox.decorate("constraint2", tools.DeltaPenalty)
#
#
#
# File d:\Programs\anaconda3\envs\test\Lib\site-packages\deap\base.py:121, in Toolbox.decorate(self, alias, *decorators)
#
#     119 function, args, kargs = pfunc.func, pfunc.args, pfunc.keywords
#
#     120 for decorator in decorators:
#
# --> 121     function = decorator(function)
#
#     122 self.register(alias, function, *args, **kargs)
#
#
#
# TypeError: DeltaPenalty.__init__() missing 1 required positional argument: 'delta'
